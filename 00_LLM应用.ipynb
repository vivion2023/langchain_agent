# %%
# 01 环境搭建 — 加载 .env 与 API Key
# 对应文档：docs/01_langchain环境搭建.md

import os
from pathlib import Path

from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

env_path = next(
    p / ".env" for p in [Path.cwd(), *Path.cwd().parents] if (p / ".env").exists()
)
load_dotenv(env_path, override=True)

os.environ["LANGCHAIN_TRACING_V2"] = os.getenv("LANGCHAIN_TRACING_V2", "true")
if os.getenv("LANGCHAIN_API_KEY"):
    os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")

deepseek_api_key = os.getenv("DEEPSEEK_API_KEY")
if not deepseek_api_key:
    raise ValueError("没有找到 DEEPSEEK_API_KEY，请先在 .env 文件中配置。")

# %%
# 02 LLM 基础调用 — 云端 DeepSeek（ChatOpenAI）
# 对应文档：docs/02_LLM基础调用.md

model = ChatOpenAI(
    model="deepseek-chat",
    api_key=deepseek_api_key,
    base_url="https://api.deepseek.com/v1",
)

response = model.invoke("你好，请问你是谁？")
print(response.content)
# Out:
# 你好！我是DeepSeek，一个由深度求索公司创造的AI助手。很高兴认识你！😊
#
# 我可以帮你解答各种问题、提供建议、进行创作、分析资料等等。无论你是想聊天、学习新知识，还是需要解决具体问题，我都乐意尽力协助。
#
# 有什么我可以帮你的吗？尽管问吧！

# %%
# 03 Ollama 本地模型 — OllamaLLM 本地推理
# 对应文档：docs/03_ollama搭建本地模型.md

from langchain_ollama.llms import OllamaLLM

model = OllamaLLM(model="deepseek-r1:1.5b")

# OllamaLLM 直接 invoke 时传入字符串
response = model.invoke("What is LangChain?")
print(response)
# Out:
# LangChain is an AI product and platform that allows businesses to leverage advanced language models for a wide range of tasks. The core idea revolves around combining the power of machine learning with natural language processing (NLP) to create intelligent, adaptive solutions.
#
# ### Key Features of LangChain:
# 1. **AI-Powered Solutions**: LangChain automates the creation of intelligent systems by using pre-trained language models to solve various business problems such as customer service, inventory management, fraud detection, and more.
#
# 2. **Smart Automation**: It can generate code, text, images, or other content with minimal manual intervention.
#
# 3. **Real-Time Insights**: By analyzing text data in real-time, LangChain can provide actionable insights directly from your business operations.
#
# 4. **Business Intelligence**: The platform integrates seamlessly with existing business tools and dashboards to help organizations make informed decisions based on data analysis.
#
# 5. **Customizable Models**: You can select from a variety of pre-trained models or train your own custom models tailored to your specific needs.
#
# 6. **Scalability**: LangChain is designed to handle large-scale businesses by providing scalable solutions that can grow with your operations.
#
# 7. **Integration Capabilities**: It works seamlessly with tools like AWS, Google Cloud, and Azure, making it easy for businesses to adopt the platform without additional complexity.
#
# ### Use Cases:
# - **Customer Service**: Automate responses to customer inquiries.
# - **Fraud Detection**: Identify patterns in data that indicate fraudulent activity.
# - **Inventory Management**: Predict demand and optimize inventory levels.
# - **Analytics Dashboard**: Generate insights from raw data quickly.
#
# LangChain is particularly useful for organizations looking to reduce manual work, improve efficiency, and gain a competitive edge through data-driven solutions.
